# %%
import torch
import torch.nn as nn
from torchvision import transforms
from PIL import Image
from torchvision import models
import matplotlib.pyplot as plt

# %%
class ModifiedCheXNet(nn.Module):
    def __init__(self, num_classes):
        super(ModifiedCheXNet, self).__init__()
        self.base_model = models.densenet121(pretrained=True)
        num_features = self.base_model.classifier.in_features
        self.base_model.classifier = nn.Linear(num_features, num_classes)

    def forward(self, x):
        return self.base_model(x)

# %%
# Load the model
num_classes=2
model1 = ModifiedCheXNet(num_classes)
model1.load_state_dict(torch.load('layer1/model1.pth'))
model1.eval()

# # Load the model
# num_classes=4
# model2 = ModifiedCheXNet(num_classes)
# model2.load_state_dict(torch.load('layer2/model2.pth'))
# model2.eval()

# # Load the model
# num_classes=9
# model3 = ModifiedCheXNet(num_classes)
# model3.load_state_dict(torch.load('layer3/model3.pth'))
# model3.eval()
# Out:
# ModifiedCheXNet(
#   (base_model): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
# ...

# %%
# Define the transformations for the image
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
image_path = 'demo_images/00002492_001.png'
image = Image.open(image_path).convert('RGB')
op = image
image = transform(image).unsqueeze(0).to('cpu')
plt.imshow(op.resize((op.size[0], op.size[1])))
plt.show()

# %%
# Pass the image through the model
with torch.no_grad():
    output = model1(image)
    _, predicted = torch.max(output.data, 1)

# %%
# Print the predicted class
if predicted.item() == 0:
    print("Normal")
else:
    print("Abnormal")
# Out:
# Normal

# %%
# Print the predicted class
if predicted.item() == 0:
    print("Normal")
else:
    print("Abnormal")
    #add gradcam code
    # Pass the input image through model2
    with torch.no_grad():
        output2 = model2(image)
        _, predicted = torch.max(output.data, 1)
        
    if output2.item() == 1:
        print("Heart Abnormality")
    elif output2.item() == 2:
        print("Pleura Abnormality")
    elif output2.item() == 3:
        print("Airway Abnormality")
    elif output2.item() == 0:
        print("Lung Abnormality")
        # Pass the input image through model2
        with torch.no_grad():
            output3 = model3(image)
            _, predicted = torch.max(output.data, 1)
        if output3.item() == 0:
            print("Atelectasis")
        elif output3.item() == 1:
            print("Consolidation")
        elif output3.item() == 2:
            print("Infiltration")
        elif output3.item() == 3:
            print("Pneumothorax")
        elif output3.item() == 4:
            print("Edema")
        elif output3.item() == 5:
            print("Emphysema")
        elif output3.item() == 6:
            print("Fibrosis")
        elif output3.item() == 7:
            print("Nodule")
        elif output3.item() == 8:
            print("Mass")
# Out:
# Abnormal

# %%
# Load and preprocess the input image
input_image = Image.open('demo_images/00000013_026.png').convert('RGB')
input_tensor = transform(input_image).unsqueeze(0)

# %%
# Pass the input image through model1
output1 = model1(input_tensor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 # Pass the input image through model1
# ----> 2 output1 = model1(input_tensor)
#
# TypeError: 'collections.OrderedDict' object is not callable

# %%
if output1.item() == 0:
    print("Normal")
else:
    print("Abnormal")
    # Pass the input image through model2
    output2 = model2(input_tensor)

    if output2.item() == 1:
        print("Heart Abnormality")
    elif output2.item() == 2:
        print("Pleura Abnormality")
    elif output2.item() == 3:
        print("Airway Abnormality")
    elif output2.item() == 0:
        print("Lung Abnormality")
        # Pass the input image through model2
    output2 = model2(input_tensor)

    if output2.item() == 1:
        print("Heart Abnormality")
    elif output2.item() == 2:
        print("Pleura Abnormality")
    elif output2.item() == 3:
        print("Airway Abnormality")
    elif output2.item() == 0:
        print("Lung Abnormality")
        # Pass the input image through model3
        output3 = model3(input_tensor)

        if output3.item() == 0:
            print("Atelectasis")
        elif output3.item() == 1:
            print("Consolidation")
        elif output3.item() == 2:
            print("Infiltration")
        elif output3.item() == 3:
            print("Pneumothorax")
        elif output3.item() == 4:
            print("Edema")
        elif output3.item() == 5:
            print("Emphysema")
        elif output3.item() == 6:
            print("Fibrosis")
        elif output3.item() == 7:
            print("Nodule")
        elif output3.item() == 8:
            print("Mass")
